# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import pickle
import time
import datetime

#Extracts the following values from each IMDB page in "With_IMDB.p".
#Stores them in a pickle'd DataFrame called "IMDB_df".
#Every name in "Cast".
#Metacritic critic score.
#Director: Done
#Release date: Done
#Budget
movielibrary = pickle.load(open("With_IMDB.p", "rb"))
movies_to_skip = pickle.load(open("Movies to skip.p", "rb"))

# %%
movie_data = []
for movie in list(movielibrary.keys()):
    print(movie)
    if movie not in movies_to_skip:
        this_movie = []
        if 'IMDB Page' in movielibrary[movie]:
            imdb = BeautifulSoup(movielibrary[movie]['IMDB Page'], "lxml")
            try:
                release_date = imdb.find(title="See more release dates").text.split(" ")
                day = release_date[0]
                if len(day)==1:
                    day = "0"+day
                month = release_date[1]
                year = release_date[2]
                release_day=datetime.datetime.strptime(month+day+year, "%B%d%Y")
            except:
                release_day = None
                movies_to_skip.add(movie)

            try:
                metacritic_critics = imdb.find(class_="titleReviewBarItem").findNext().findNext().text
                if " " not in metacritic_critics:
                    score = int(metacritic_critics.strip())
                else:
                    score = None
            except:
                score = None
                

            try:
                director = imdb.find(class_="credit_summary_item").find("a").text
            except: 
                director = None
                
            try:
                budget = imdb.find(text="Budget:").findParent().findParent()
                budgetNum = budget.text
            except:
                budgetNum = None
                

            try:
                cast = []
                table = imdb.find("table", class_= "cast_list")
                for t in table.find_all("tr")[1:]:
                    name =  t.find_all("td")[1].text
                    cast.append(name)
            except:
                cast = None
                
            movie_data.append([movie, release_day, score, director, cast, budgetNum])
            movielibrary[movie]=None
        else:
            print(movie)
            movies_to_skip.add(movie)
# Out:
# Avengers: Endgame
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-573cf265cb3f> in <module>
#       4     if movie not in movies_to_skip:
#       5         this_movie = []
# ----> 6         if 'IMDB Page' in movielibrary[movie]:
#       7             imdb = BeautifulSoup(movielibrary[movie]['IMDB Page'], "lxml")
#       8             try:
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
imdb_features = pd.DataFrame(data=movie_data, columns = ["Name", "Release Date", "Metacritic Critic Score", "Director", "Cast", "IMDB's Budget"])

# %%
pickle.dump(imdb_features, open("IMDB_df.p", "wb"))

# %%
imdb_features
# Out:
#                                                Name Release Date  \
# 0                                 Avengers: Endgame   2019-04-26
# 1                                     The Lion King   2019-07-19
# 2     Star Wars: Episode IX - The Rise of Skywalker   2019-12-20
# 3                                         Frozen II   2019-11-22
# 4                                       Toy Story 4   2019-06-21
# ...                                             ...          ...
# 5128                                         Khumba   2013-04-12
# 5129                                       Remnants   2013-05-01
# 5130                                Billy and Buddy   2013-05-30
# 5131                         I Spit on Your Grave 2   2013-03-29
# 5132                  Into the White2013 Re-release   2012-06-29
#
#       Metacritic Critic Score          Director  \
# 0                        78.0     Anthony Russo
# 1                        55.0       Jon Favreau
# 2                        53.0       J.J. Abrams
# 3                        64.0        Chris Buck
# 4                        84.0       Josh Cooley
# ...                       ...               ...
# 5128                      NaN       Petter Næss
# 5129                      NaN    Aram Rappaport
# 5130                     44.0  Farren Blackburn
# 5131                      NaN        Bill Stone
# 5132                     52.0  Johannes Roberts
#
#                                                    Cast IMDB's Budget
# 0     [\n Robert Downey Jr.\n , \n Chris Evans\n , \...   356000000\n
# 1     [\n Chiwetel Ejiofor\n , \n John Oliver\n , \n...   260000000\n
# 2     [\n Carrie Fisher\n , \n Mark Hamill\n , \n Ad...   275000000\n
# 3     [\n Kristen Bell\n , \n Idina Menzel\n , \n Jo...   150000000\n
# 4     [\n Tom Hanks\n , \n Tim Allen\n , \n Annie Po...   200000000\n
# ...                                                 ...           ...
# 5128  [\n Florian Lukas\n , \n David Kross\n , \n St...          None
# 5129  [\n Juan Luis Acevedo\n , \n Kirstie Alley\n ,...     2500000\n
# 5130                                               None          None
# 5131  [\n Paul Drouin\n , \n Chris Overing\n , \n Sc...          None
# 5132                                               None          None
#
# [5133 rows x 6 columns]

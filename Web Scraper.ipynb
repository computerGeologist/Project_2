# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import pickle
import random
import time
import re

# %%
def loadPage(url):
    '''
    Given a page URL, returns a tuple that contains the BeautifulSoup of that page, followed by the text of that page.
    '''
    response = requests.get(url, headers={'User-agent': "Mozilla/5.0"})
    return BeautifulSoup(response.text, 'lxml'), response.text

# %%
#Box Office Mojo has two types of pages I want. The first is the weekly domestic box office table,
#and the other is the general summary. 

def find_domestic_link(title_summary_BS):
    '''Given the BeautifulSoup of a summary page like https://www.boxofficemojo.com/title/tt1568911/, returns 
    the weekly domestic releases URL, ex. https://www.boxofficemojo.com/release/rl880313857/weekly/?ref_=bo_rl_tab#tabs
    '''
    url_mid = title_summary_BS.find(class_="a-section a-spacing-none a-spacing-top-base").find("a", text="Domestic")['href']
    url_sections = url_mid.split("/")
    main_section = url_sections[2].split("?")[0]
    return "https://www.boxofficemojo.com/release/" + main_section+"/weekly/?ref_=bo_rl_tab"

def findTitleSummary(weekly_domestics_BS):
    '''Given the BeautifulSoup of the domestic weekly relases, like https://www.boxofficemojo.com/release/rl880313857/weekly/?ref_=bo_rl_tab#tabs, returns 
    the summary page URL , ex. https://www.boxofficemojo.com/title/tt1568911/
    '''
    try:
        title_summary = weekly_domestics_BS \
        .find("a", class_='a-link-normal mojo-title-link refiner-display-highlight') \
        .get("href")
        return "https://www.boxofficemojo.com"+title_summary
    except:
        return None
    
def summary_url_to_IMDB_url(box_office_mojo_url):
    '''Given a title summary URL, like https://www.boxofficemojo.com/title/tt1568911/, returns the IMDB URL: https://www.imdb.com/title/tt1568911/'''
    try:
        return "https://www.imdb.com/title/" + box_office_mojo_url.split("/")[4] + "/"
    except:
        return None

# %%
#Static definition of years. Range excludes 2020 due to the pandemic.
years_to_scrape = [2014, 2015, 2016, 2017, 2018, 2019]

# %%
lines = []
links = []

#First, create a collection of links to scrape. For each year, acquire all movies that released that year.

for year in years_to_scrape:
    #This page contains all movies released during this year, including rereleases, and sorted by total gross.
    movies_page_url = "https://www.boxofficemojo.com/year/"+str(year)+"/?grossesOption=totalGrosses"
    print(movies_page_url)
    movies_page = None
    while (movies_page == None):
        try:
            movies_page = loadPage(movies_page_url)[0]
            movies_table = movies_page.find("table").find_all("tr")
        except:
            print("Exception")
            movies_page = None
            time.sleep(3)
    
        
    
    time.sleep(0.2)

    movies_table = movies_page.find("table").find_all("tr")


    for t in movies_table:
        newline = []
        link = t.find("a")
        if link:
            links.append(link.get("href"))
        newline = [c.text for c in t.find_all("td")+t.find_all("th")]
        lines.append(newline)

    names = [l[1] for l in lines[1:]]
    list_of_weekly_links = []
    for l in links[1:]:
        try:
            this_id = l.split("/")[2]
            list_of_weekly_links.append("https://www.boxofficemojo.com/release/"+this_id+"/weekly/")
        except:
            this_id = None
            print(l)
# Out:
# https://www.boxofficemojo.com/year/2014/?grossesOption=totalGrosses
# https://www.boxofficemojo.com/year/2015/?grossesOption=totalGrosses
# ?grossesOption=totalGrosses&sort=rank&ref_=bo_yld__resort#table
# https://www.boxofficemojo.com/year/2016/?grossesOption=totalGrosses
# ?grossesOption=totalGrosses&sort=rank&ref_=bo_yld__resort#table
# ?sort=rank&grossesOption=totalGrosses&ref_=bo_yld__resort#table
# https://www.boxofficemojo.com/year/2017/?grossesOption=totalGrosses
# ?grossesOption=totalGrosses&sort=rank&ref_=bo_yld__resort#table
# ?sort=rank&grossesOption=totalGrosses&ref_=bo_yld__resort#table
# ?grossesOption=totalGrosses&sort=rank&ref_=bo_yld__resort#table
# https://www.boxofficemojo.com/year/2018/?grossesOption=totalGrosses
# ?grossesOption=totalGrosses&sort=rank&ref_=bo_yld__resort#table
# ?sort=rank&grossesOption=totalGrosses&ref_=bo_yld__resort#table
# ?grossesOption=totalGrosses&sort=rank&ref_=bo_yld__resort#table
# ?grossesOption=totalGrosses&sort=rank&ref_=bo_yld__resort#table
# https://www.boxofficemojo.com/year/2019/?grossesOption=totalGrosses
# ?grossesOption=totalGrosses&sort=rank&ref_=bo_yld__resort#table
# ?sort=rank&grossesOption=totalGrosses&ref_=bo_yld__resort#table
# ?grossesOption=totalGrosses&sort=rank&ref_=bo_yld__resort#table
# ?grossesOption=totalGrosses&sort=rank&ref_=bo_yld__resort#table
# ?sort=rank&grossesOption=totalGrosses&ref_=bo_yld__resort#table

# %%
def scrape_weekly_to_table(index_name, url, sleep=0, table = [], summary_page_urls = [], movies_to_skip=[]):
    '''
    Scrapes a weekly page from a Box Office Mojo URL, and adds its value to a table, 'table'. 
    index_name: The index, which is the first column. 
    url: The URL to scrape
    sleep: Time to sleep between each call.
    table: The table to add the values in the weekly table to.
    summary_page_urls: Locate the URL for the summary page in this step, and add them to this list.
    '''
    page,text = loadPage(url)
    time.sleep(sleep)
    
    next_ = findTitleSummary(page)
    if next_ != None:
        summary_page_urls.append((index_name, findTitleSummary(page)))
    else: 
        movies_to_skip.add(index_name)
    
    
    main_table = page.find("table")
        
    #The movie name was originally determined by clicking on a link with the name in the Name column.
    #Now, grab the page title to determine what it actually is- "Name".
    title = page.find("h1", class_="a-size-extra-large")
    if main_table!=None and title!=None:        
        
        real_title = title.text
        for row in main_table.find_all("tr")[1:]:
            newrow = [index_name, real_title]

            for item in row.find_all("td"):
                newrow.append(item.text)
            table.append(newrow)
    else:
        movies_to_skip.add(index_name)
    return table, summary_page_urls

def scrape_all_weeklies(cols = ["index_name","Name", "Date", "Rank", "Weekly", "%LW", "Theaters", "Change", "Avg", "To Date", "Week", "Estimated"]):
    '''Returns a dataframe containing weekly data, plus an array of URLS for the next step'''
    table = []
    summary_urls = []
    movies_to_skip = pickle.load(open("Movies to skip.p", "rb"))
    for name, url in zip(names, list_of_weekly_links):
        if name not in movies_to_skip:
            print(name)
            table, summary_urls = scrape_weekly_to_table(name, url, 0.1, table, summary_urls, movies_to_skip)
    pickle.dump(movies_to_skip, open("Movies to skip.p", "wb"))
    return pd.DataFrame(data=table, columns= cols), summary_urls

# %%
def scrape_summary_to_table(index_name, url, sleep=0, table=[], imdb_urls = [], movies_to_skip=[]):
    '''
    Scrapes a Box Office Mojo summary page, and builds a list of its properties. 
    '''
    try:
        page, text=loadPage(url)
    except:
        print(index_name)
        print(url)
        return a+1
    
    time.sleep(sleep)

    imdb_urls.append((index_name, summary_url_to_IMDB_url(url)))

    main_table = page.find(class_="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile")

    if main_table!=None:
        budget_ = main_table.find(text="Budget")
        if budget_ !=None:
            budget = budget_.findNext().text
        else:
            budget = None

        mpaa_ = main_table.find(text="MPAA")
        if mpaa_ != None: 
            mpaa = mpaa_.findNext().text
        else: 
            mpaa=None

        genres_ = main_table.find(text="Genres")
        if genres_ !=None:
            genres = set(re.split(" |\n", genres_.findNext().text))
        else:
            genres = set({})

        opening_ = main_table.find(text="Opening")
        if opening_ !=None:
            opening = opening.findNext().text
        else:
            opening = None

        runtime_ = main_table.find(text="Running Time")
        if runtime_ !=None:
            runtime = runtime_.findNext().text
        else:
            runtime = None

        table.append([index_name, budget, mpaa, genres, opening, runtime])

    else:
        print(index_name)
        movies_to_skip.add(index_name)
    return table, imdb_urls

def scrape_all_summaries(summary_urls, cols = ["index_name", "Budget", "MPAA", "Genres", "Domestic Opening", "Running Time"]):
    '''
    Scrapes all summaries into a DataFrame. Returns that dataframe, plus a table of the next set of URLS.
    '''
    table = []
    imdb_urls = []
    movies_to_skip = pickle.load(open("Movies to skip.p", "rb"))
    for index_name, url in summary_urls:
        if index_name not in movies_to_skip:
            print(index_name)
            table, imdb_urls = scrape_summary_to_table(index_name, url, 0.1, table, imdb_urls, movies_to_skip)
    pickle.dump(movies_to_skip, open("Movies to skip.p", "wb"))
    return pd.DataFrame(data=table, columns= cols), imdb_urls

# %%
def scrape_IMDB_to_table(index_name, url, sleep=0, table=[], movies_to_skip=[]):
    
    page, text=loadPage(url)
    time.sleep(sleep)
    
    try:
        release_date = page.find(title="See more release dates").text.split(" ")
        day = release_date[0]
        if len(day)==1:
            day = "0"+day
        month = release_date[1]
        year = release_date[2]
        release_day=datetime.datetime.strptime(month+day+year, "%B%d%Y")
    except:
        release_day = None

    try:
        metacritic_critics = page.find(class_="titleReviewBarItem").findNext().findNext().text
        if " " not in metacritic_critics:
            score = int(metacritic_critics.strip())
        else:
            score = None
    except:
        score = None


    try:
        director = page.find(class_="credit_summary_item").find("a").text
    except: 
        director = None

    try:
        budget = page.find(text="Budget:").findParent().findParent().text
    except:
        budget = None

    try:
        cast = []
        cast_table = page.find("table", class_= "cast_list")
        for t in cast_table.find_all("tr")[1:]:
            name =  t.find_all("td")[1].text
            cast.append(name)
    except:
        cast = None
    
    table.append([index_name, release_day, score, director, cast, budget])
    return table

def scrape_all_imdbs(imdb_urls, cols = ["index_name", "Release Date", "Metacritic Critic Score", "Director", "Cast", "IMDB's Budget"]):
    table = []
    movies_to_skip = pickle.load(open("Movies to skip.p", "rb"))
    for index_name, url in imdb_urls:
        if index_name not in movies_to_skip:
            print(index_name)
            table = scrape_IMDB_to_table(index_name, url, 2+random.random(), table, movies_to_skip)
    pickle.dump(movies_to_skip, open("Movies to skip.p", "wb"))
    return pd.DataFrame(data=table, columns=cols)

# %%
weeklies, summary_urls = scrape_all_weeklies()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-793b82e48057> in <module>
# ----> 1 weeklies, summary_urls = scrape_all_weeklies()
#
# <ipython-input-5-eaa9b21f510f> in scrape_all_weeklies(cols)
#      41     summary_urls = []
#      42     movies_to_skip = pickle.load(open("Movies to skip.p", "rb"))
# ---> 43     for name, url in zip(names, list_of_weekly_links):
#      44         if name not in movies_to_skip:
#      45             print(name)
#
# NameError: name 'names' is not defined

# %%
summaries, imdb_urls = scrape_all_summaries(summary_urls)
# Out:
# Guardians of the Galaxy
# The Hobbit: The Battle of the Five Armies
# Transformers: Age of Extinction
# Maleficent
# X-Men: Days of Future Past
# Big Hero 6
# Dawn of the Planet of the Apes
# 22 Jump Street
# Teenage Mutant Ninja Turtles
# Neighbors
# Ride Along
# Ride Along
# Rio 2
# Into the Woods
# Lucy
# Night at the Museum: Secret of the Tomb
# Mr. Peabody & Sherman
# The Maze Runner
# Non-Stop
# Heaven Is for Real
# The Imitation Game
# Fury
# Annabelle
# Penguins of Madagascar
# Let's Be Cops
# The Monuments Men
# The Purge: Anarchy
# Exodus: Gods and Kings
# The Nut Job
# Son of God
# The Grand Budapest Hotel
# Planes: Fire & Rescue
# RoboCop
# Dracula Untold
# The Hundred-Foot Journey
# Selma
# Muppets Most Wanted
# Ouija
# The Boxtrolls
# The Book of Life
# About Last Night
# Into the Storm
# The Judge
# Blended
# St. Vincent
# A Million Ways to Die in the West
# Birdman or (The Unexpected Virtue of Ignorance)
# The Expendables 3
# The Expendables 3
# Earth to Echo
# Earth to Echo
# The Theory of Everything
# The Theory of Everything
# This Is Where I Leave You
# Paranormal Activity: The Marked Ones
# Nightcrawler
# Chef
# Get on Up
# When the Game Stands Tall
# Oculus
# A Walk Among the Tombstones
# That Awkward Moment
# Boyhood
# Top Five
# The November Man
# Endless Love
# Pompeii
# Brick Mansions
# I, Frankenstein
# I, Frankenstein
# Bears
# Addicted
# A Most Wanted Man
# The Single Moms Club
# And So It Goes
# Step Up All In
# Big Eyes
# America: Imagine the World Without Her
# Left Behind
# Winter's Tale
# Foxcatcher
# Belle
# Magic in the Moonlight
# Sabotage
# Moms' Night Out
# Inherent Vice
# Vampire Academy
# Meet the Mormons
# A Most Violent Year
# The Skeleton Twins
# The Skeleton Twins
# The Wind Rises
# Dear White People
# The Lunchbox2013 Re-release
# Fading Gigolo
# Fading Gigolo
# Calvary
# Ghostbusters30th Anniversary Release
# Mommy
# The Grand Seduction
# Veronica Mars
# Veronica Mars
# Obvious Child
# The Identical
# The Pyramid
# The Good Lie
# The Raid 2
# Dragon Ball Z: Battle of Gods
# Ode To My Father
# 2 States
# 2 States
# Le Week-end
# The Oscar Nominated Short Films 2014: Live Action
# Words and Pictures
# The Immigrant
# Awake: The Life of Yogananda
# Finding Vivian Maier
# Pride
# Gimme Shelter
# Force Majeure
# Jai Ho
# Jai Ho
# Singham Returns
# The Remaining
# The Rover
# Walking with the Enemy
# Leviathan
# Laggies
# 50 to 1
# Stalingrad
# The Song
# The Song
# The Babadook
# Atlas Shrugged: Who Is John Galt?
# Kochadaiiyaan
# Saw10th Anniversary Release
# Life Itself
# Breakup Buddies
# The Villain
# Yves Saint Laurent
# Khoobsurat
# Men, Women & Children
# Men, Women & Children
# The Tale of The Princess Kaguya
# Frankie & Alice2014 Re-release
# A Matter of Faith
# Jodorowsky's Dune
# Hasee Toh Phasee
# Mary Kom
# Finding Fanny
# Fleet of Time
# Dom Hemingway
# A Hard Day's Night2014 Re-release
# A Hard Day's Night2014 Re-release
# The One I Love
# Tracks
# The Two Faces of January
# A Girl Walks Home Alone at Night
# Last Days in Vietnam
# In Secret
# But Always
# She's Beautiful When She's Angry
# The Pirates
# Goodbye to Language
# The Bride of Humpty Sharma
# Women Who Flirt
# Glen Campbell: I'll Be Me
# Omar
# The Chef
# Jimi: All Is by My Side
# Nymphomaniac: Vol. II
# Stranger by the Lake
# On My Way
# Happy Ending
# I Am Eleven2014 Re-release
# A Five Star Life2014 Re-release
# Innocence
# The Dance of Reality
# Antarctica: A Year on Ice
# The Last of Robin Hood
# Elsa & Fred
# Kundo: Age of the Rampant
# The Unknown Known
# I'm Your Hero
# Love on the Cloud
# Life of Crime
# Ernest & Celestine
# Blue Ruin
# The Green Prince
# The Zero Theorem
# Action Jackson
# National Gallery
# Tazza: The Hidden Card
# Art and Craft
# Diplomacy
# The Suspect
# Supermensch
# Supermensch
# The Breakup Guru
# Rob the Mob
# Jinn
# Listen Up Philip
# A Summer's Tale
# Code Black
# Anita: Speaking Truth to Power
# Evangelion: 3.0 You Can (Not) Redo
# That Demon Within
# Keep on Keepin' On
# Sinbad: The Fifth Voyage
# Alan Partridge
# Mistaken for Strangers
# The Congress2013 Re-release
# The Divine Move
# The Divine Move
# The Jewish Cardinal
# Make Your Move
# Knights of Badassdom
# Afflicted
# Finding Fela
# Zero Motivation
# God the Father
# The Liberator
# The Overnighters
# Anohana the Movie: The Flower We Saw That Day (Ano hi mita hana no namae wo bokutachi wa mada shiran
# Ivory Tower
# Six Dance Lessons in Six Weeks
# God Help the Girl
# Coherence
# The Way He Looks
# One Chance
# One Chance
# Beyond Sight: The Derek Rabelo Story
# Child's Pose
# Hiroshima Mon Amour2014 Re-release
# Generation War
# Generation War
# Pump
# The Principle
# Life After Beth
# Advanced Style
# Visitors
# 12 O'Clock Boys
# 12 O'Clock Boys
# Water & Power
# Whitey: United States of America v. James J. Bulger
# Je t'aime, je t'aime2014 Re-release
# A Letter to Momo
# Through a Lens Darkly: Black Photographers and the Emergence of a People
# Jealousy
# Jealousy
# Heroic Antics
# No Tears for the Dead
# The Last Sentence
# Young & Beautiful
# Bicycling with Molière
# Wetlands2014 Re-release
# Cheap Thrills
# Walk of Shame
# The One I Wrote for You
# Sagrada: The Mystery of Creation2014 Re-release
# The Conformist2014 Re-release
# Rudderless
# Borgman
# The Rocket
# Ilo Ilo
# The Bag Man
# In Bloom
# Hellion
# Half of a Yellow Sun
# Low Down
# Hateship Loveship
# 1,000 Times Good Night
# At Middleton
# The Missing Picture
# NOW: In the Wings on a World Stage
# Lucky Them
# The Internet's Own Boy: The Story of Aaron Swartz
# A Birder's Guide to Everything
# American Mustang
# Decoding Annie Parker
# A Master Builder
# A Master Builder
# Monk with a Camera
# Filmistaan
# Return to the Hiding Place
# There's No Place Like Utopia
# The Dog
# If You Build It
# Road to Ninja - Naruto the Movie2014 Re-release
# Road to Ninja - Naruto the Movie2014 Re-release
# Next Goal Wins
# Interior. Leather Bar.
# Blood Ties
# Blood Ties
# The Last of the Unjust
# Teenage
# Child of God
# The Expedition to the End of the World
# Dead Snow 2: Red vs. Dead
# Le Jour Se Leve
# Beneath the Harvest Sky
# Beneath the Harvest Sky
# White Bird in a Blizzard
# It Felt Like Love
# Big Bad Wolves
# For a Woman
# The Hero of Color City
# Bird People
# Documented
# Southern Baptist Sissies
# A Long Way Off
# Manakamana
# Yellow Day
# Othello
# Why Don't You Play in Hell?
# Closed Curtain
# The King and the Mockingbird2014 Re-release
# The King and the Mockingbird2014 Re-release
# Level Five
# Elena
# Elena
# Christian Mingle
# Adult World
# Born to Fly: Elizabeth Streb vs. Gravity
# Two Lives
# The Decent One
# Memphis
# NightLights
# The Sacrifice2014 Re-release
# Lekar Hum Deewana Dil
# The Great Flood
# Coming Up Roses2014 Re-release
# Run & Jump
# The Past is a Grotesque Animal
# Guardian Angel
# A Picture of You
# Actress
# Tasting Menu
# Tosca's Kiss
# On Tour with Pina Bausch
# Kelly & Cal
# The Homestretch
# Stand Clear of the Closing Doors
# Accident2014 Re-release
# Cold Comes the Night
# Cold Comes the Night
# Hank and Asha
# Hank and Asha
# Burning Bush
# Magician: The Astonishing Life and Work of Orson Welles
# Horses of God2014 Re-release
# Exhibition
# The Pretty One
# War of the Worlds: Goliath
# A Long Way Down
# Camp X-Ray
# Days and Nights
# Sol LeWitt
# The Pleasures of Being Out of Step
# Alien Abduction
# Concerning Violence
# Bhopal: A Prayer for Rain
# Boy Meets Girl
# Touch the Wall
# Wolves
# In No Great Hurry: 13 Lessons in Life with Saul Leiter
# Queen Margot2014 Re-release
# Queen Margot2014 Re-release
# Revenge of the Mekons
# Revenge of the Mekons
# Living Is Easy with Eyes Closed
# You're Not You
# The Final Member
# The Amazing Catfish
# Dishkiyaoon
# Policeman
# The Players
# Inside the Mind of Leonardo
# The Endless Summer
# Marius
# Marius
# On the Other Side of the Tracks
# Radio Free Albemuth
# The Immortalists
# The Sacrament
# The Sacrament
# Fanny
# Comet
# The Mystery of Happiness
# The Quitter
# Canopy
# Almost Human
# Red Hollywood
# Love is in the Air2013 Re-release
# Gringo Trails
# Life Partners
# The Empty Hours
# Gladiators of Rome
# Rigor Mortis
# Archipelago2014 Re-release
# Come Back to Me
# The Little Bedroom2014 Re-release
# The Strange Color of Your Body's Tears
# ABCs of Death 2
# Very Good Girls
# Pioneer
# Will You Still Love Me Tomorrow?
# Aatsinki: The Story of Arctic Cowboys
# Jews of Egypt
# The Adventurer: The Curse of the Midas Box
# The Adventurer: The Curse of the Midas Box
# Manuscripts Don't Burn
# Love & Air Sex
# Gang of Ghosts
# Infliction
# 2 Autumns, 3 Winters
# The Devil's Hand
# The Devil's Hand
# Papirosen
# Gabrielle
# The Only Real Game
# Return to Nuke 'Em High Volume 1
# The Sleepwalker
# Nothing Bad Can Happen
# Half The Road: The Passion, Pitfalls & Power of Women's Professional Cycling
# Death Metal Angola
# Smiling Through the Apocalypse
# Free the Nipple
# Thunder and the House of Magic
# Maidan
# Swim Little Fish Swim
# Hollidaysburg
# Stop The Pounding Heart
# Hide Your Smiling Faces
# The Hacker Wars
# Aftermath
# Life's a Breeze2014 Re-release
# Age of Uprising: The Legend of Michael Kohlhaas
# The Girl on the Train
# What Now? Remind Me
# V/H/S Viral
# Mercedes Sosa: The Voice of Latin America
# Refuge
# Indigo Children
# McCanick
# Evergreen: The Road to Legalization
# The Right Kind of Wrong
# Algorithms
# More Than the Rainbow
# Summer in February
# Rhymes for Young Ghouls
# Postman Pat: The Movie
# Souldier
# Ragnarok
# The Tower
# Anything for Alice
# Avengers: Age of Ultron
# Inside Out
# The Hunger Games: Mockingjay - Part 2
# Cinderella
# Spectre
# Mission: Impossible - Rogue Nation
# Ant-Man
# Home
# Hotel Transylvania 2
# Fifty Shades of Grey
# San Andreas
# Mad Max: Fury Road
# The Peanuts Movie
# Kingsman: The Secret Service
# The Good Dinosaur
# Trainwreck
# Creed
# Tomorrowland
# Get Hard
# Sisters
# Alvin and the Chipmunks: The Road Chip
# Ted 2
# Goosebumps
# Paddington
# Bridge of Spies
# The Big Short
# The Visit
# Black Mass
# Vacation
# The Perfect Guy
# Fantastic Four
# The Hateful Eight
# Southpaw
# Insidious: Chapter 3
# Poltergeist
# The Man from U.N.C.L.E.
# Everest
# The Night Before
# Krampus
# The Age of Adaline
# Brooklyn
# The Boy Next Door
# Pan
# Hot Pursuit
# Concussion
# The DUFF
# The Second Best Exotic Marigold Hotel
# Chappie
# Crimson Peak
# A Walk in the Woods
# Point Break
# Point Break
# Ricki and the Flash
# Run All Night
# The Lazarus Effect
# Ex Machina
# In the Heart of the Sea
# The Gallows
# The Gallows
# Hitman: Agent 47
# Project Almanac
# Project Almanac
# Black or White
# Aloha
# Shaun the Sheep Movie
# Still Alice
# Paranormal Activity: The Ghost Dimension
# Dope
# Seventh Son
# Seventh Son
# Monkey Kingdom
# Room
# It Follows
# It Follows
# American Ultra
# Burnt
# Do You Believe?
# Love & Mercy
# Strange Magic
# The 33
# The Danish Girl
# The Danish Girl
# Huevos: Little Rooster's Egg-cellent Adventure
# Amy
# Dragon Ball Z: Resurrection "F"
# Blackhat
# Trumbo
# Trumbo
# I'll See You in My Dreams
# The Green Inferno
# Grandma
# Baahubali: The Beginning
# Bajirao Mastani
# Little Boy
# The Loft
# Danny Collins
# 90 Minutes in Heaven
# Suffragette
# Found a Treasure Called Love
# 45 Years
# The Water Diviner
# Irrational Man
# Anomalisa
# Scouts Guide to the Zombie Apocalypse
# A la mala
# We Are Your Friends
# Wild Tales
# Ladrones
# Rock the Kasbah
# The End of the Tour
# He Named Me Malala
# Captive
# Truth
# Mistress America
# Meru
# WARx2
# My All-American
# Jem and the Holograms
# Cake
# Game of Thrones Season 4 Finale
# Testament of Youth
# The Diary of a Teenage Girl
# I
# 99 Homes
# Welcome Back
# The Cokeville Miracle
# The Salt of the Earth
# Iris
# Lost in Hong Kong
# The Wolfpack
# Goodbye Mr. Loser
# '71
# Mojin: The Lost Legend
# Child 44
# Goodnight Mommy
# Miss You Already
# Timbuktu
# 5 Flights Up
# Big Stone Gap
# Patterns of Evidence: Exodus
# Boruto: Naruto The Movie
# Singh Is Bliing
# Mustang
# Sleeping with Other People
# Seymour: An Introduction
# The Stanford Prison Experiment
# The Stanford Prison Experiment
# Kumiko, The Treasure Hunter
# Welcome to Me
# Welcome to Me
# Detective Byomkesh Bakshy!
# Jimmy's Hall
# By the Sea
# Gabbar is Back
# The Last: Naruto the Movie
# Peggy Guggenheim: Art Addict
# Steve Jobs: The Man in the Machine
# Phantom
# Darbareye Elly2015 Re-release
# Let's Get Married
# Bombay Velvet
# Attack on Titan Part 1
# The Third Man2015 Re-release
# Rosenwald
# Rosenwald
# Saint Laurent
# Heart of a Dog
# Janis: Little Girl Blue
# Unbranded
# Unbranded
# The Apu TrilogyTriple Bill
# Freetown
# Coming Home
# Katti Batti
# Katti Batti
# Kahlil Gibran's The Prophet
# Effie Gray
# Noble2014 Re-release
# Talvar
# Northern Limit Line
# Ballet 422
# Taxi
# Good Kill
# David and Goliath
# David and Goliath
# N.H 10
# The Man in 3B
# Above and Beyond
# Above and Beyond
# Go Away Mr. Tumor
# White God
# White God
# A Borrowed Identity
# In the Name of My Daughter
# Love
# Carter High
# Hamari Adhuri Kahani
# A Royal Night Out
# A Pigeon Sat on a Branch Reflecting on Existence
# 2001: A Space Odyssey2014 Re-release
# Chocolate City
# Dark Places
# Heneral Luna
# Escobar: Paradise Lost
# The Connection
# Lost and Love
# Stonewall
# Stonewall
# The Priests
# Lambert & Stamp
# An Honest Liar
# Serena
# The Young and Prodigious T.S. Spivet
# The Young and Prodigious T.S. Spivet
# A Brilliant Young Mind
# Zhongkui: Snow Girl and the Dark Crystal
# C'est Si Bon
# The Last Women Standing
# After the Ball
# Hell and Back
# Hell and Back
# Experimenter
# Good Day, Ramon
# Samba
# The Tribe
# Tangerines
# Yellow Day2015 Re-release
# Ingrid Bergman: In Her Own Words
# Cop Car
# Cop Car
# Don't Think I've Forgotten: Cambodia's Lost Rock and Roll
# Devil and Angel
# Mississippi Grind
# Mississippi Grind
# Kung Fu Jungle
# The Boy and the World2015 Re-release
# A Journey Through Time with Antony
# Boulevard
# Do I Sound Gay?
# The Goonies2015 Re-release
# Road Hard
# She's Funny That Way
# Memories of the Sword
# Adult Beginners
# Chronicles of Evil
# A Lego Brickumentary
# Man from Reno
# Man from Reno
# A Poem Is a Naked Person
# Saving Mr. Wu
# Christmas Eve
# Queen of Earth
# Beasts of No Nation
# Dark Horse
# Sunshine Superman
# Tab Hunter Confidential
# Trace Amounts
# Heaven Knows What
# Nasty Baby
# The Wonders
# Freaks of Nature
# I Am Big Bird: The Caroll Spinney Story
# The Messenger
# People Places Things
# Our Little Sister
# Dark Star: HR Gigers Welt
# Flowers
# Gueros
# I Smile Back
# The Search for General Tso
# The Ark of Mr Chow
# Beloved Sisters
# We Come as Friends
# The Yes Men Are Revolting
# The Advocate: A Missing Body
# Heist
# Red Herring
# The Seven Five
# Bangistan
# Appropriate Behavior
# Shanghai2015 Re-release
# Beyond the Reach
# Lost River
# The Salvation
# River of Fundament
# River of Fundament
# Madame Bovary
# Charlie's Country
# Queen & Country
# Queen & Country
# Love Thy Nature
# The New Rijksmuseum - The Film
# The New Rijksmuseum - The Film
# The Phone
# Prophet's Prey
# Lila & Eve
# Match2015 Re-release
# Before We Go
# Grey Gardens
# Sister Code
# Knock Knock
# Knock Knock
# Welcome to Leith
# Finders Keepers
# Wild City
# The Forbidden Room
# Pierrot le Fou2015 Re-release
# The Winding Stream
# Song One
# Love Forecast
# Amira & Sam
# 3 1/2 Minutes, 10 Bullets
# Runoff
# Paulette2015 Re-release
# Paulette2015 Re-release
# Rebels of the Neon God
# Americons
# Like Sunday, Like Rain
# 7 Chinese Brothers
# 7 Chinese Brothers
# Bikes vs Cars
# The Cut
# Sembene!
# The Keeping Room
# Rediscover SautetFilm Festival
# R100
# Unexpected
# Can't Stand Losing You: Surviving the Police
# Hippocrates: Diary of a French Doctor
# Salut d'Amour
# Metropolitan2015 Re-release
# Slow Learners
# Mediterranea
# Mediterranea
# Animals2015 Re-release
# Noma: My Perfect Storm
# Noma: My Perfect Storm
# Consumed
# Boy Meets Girl
# Futuro Beach
# Forbidden Games
# Misery Loves Comedy
# Going Away
# A Hard Day
# The Challenger
# Ardor
# Gangnam 1970
# The Great Museum
# The Other One
# Butterfly Girl
# Trash
# Eastern Boys
# The World of Kanako2015 Re-release
# Who Took Johnny
# Life in a Walk
# The Human Centipede III (Final Sequence)
# A Reason
# Full Moon in Paris
# Cheatin'
# 10 Days in a Madhouse
# Buzzard
# Gone Doggy Gone
# Backcountry
# Yakuza Apocalypse
# Yakuza Apocalypse
# 10.000 Km
# The Armor of Light
# Arabian Nights: Volume 1 - The Restless One
# A Murder in the Park
# A Murder in the Park
# Of Horses and Men
# Dreams Rewired
# Emptying the Skies
# Kidnapping of Michel Houellebecq
# Just Before I Go
# Digging Up the Marrow
# Mala Mala
# The Forecaster
# Little Accidents
# The Life and Mind of Mark DeFriest
# The Life and Mind of Mark DeFriest
# Still Life
# An Eye for Beauty
# Every Thing Will Be Fine
# Every Thing Will Be Fine
# The Lesson
# Station to Station
# Station to Station
# B-Side
# The Pardon
# Paulo Coelho's Best Story
# Meet Me in Montenegro
# Counting
# A Fool
# Jellyfish Eyes
# Steak (R)evolution
# Straight Outta Tompkins
# One Small Hitch2015 Re-release
# Kilo Two Bravo
# The Great Man
# Area 51
# Rubble Kings
# The Film Critic
# The Sisterhood of Night
# Horse Money
# Arabian Nights: Volume 2 - The Desolate One
# Alleluia
# The Night of the Shooting Stars2015 Re-release
# The Marquise of O
# Sex, Death and Bowling
# Medeas
# Black November
# The Wanted 18
# This Isn't Funny
# Chic!
# Our Man in Tehran
# The Living
# Far from Men
# The Dead Lands
# On War2015 Re-release
# SBK: The Movie
# Gerontophilia2015 Re-release
# Guidance
# Miss Hill: Making Dance Matter
# Ashby
# Arabian Nights: Volume 3 - The Enchanted One
# The Summer of Sangaile
# Farewell, Herr Schwarz
# Club Life
# Back to the Jurassic
# Days of Grace2015 Re-release
# Set Fire to the Stars
# The Knife of Don Juan
# Salvation Army
# Unfreedom
# The Free Speech Apocalypse
# In the Basement
# Hyena
# Mi America
# Know How
# Know How
# Julia
# Chocolat2015 Re-release
# Body
# Anita Ho
# Anita Ho
# The Lady in the Car with Glasses and a Gun
# Me You and Five Bucks
# Me You and Five Bucks
# Dark Forest
# Drown
# Forever
# Childless
# They Are We
# Le talent de mes amis
# Big Muddy
# It's All So Quiet2015 Re-release
# United Passions
# United Passions
# Lou!
# Paranoid Girls
# Rogue One: A Star Wars Story
# Rogue One: A Star Wars Story
# Finding Dory
# Captain America: Civil War
# The Secret Life of Pets
# The Jungle Book
# Deadpool
# Zootopia
# Suicide Squad
# Sing
# Doctor Strange
# Hidden Figures
# X-Men: Apocalypse
# La La Land
# Kung Fu Panda 3
# Ghostbusters
# Ghostbusters
# Central Intelligence
# The Legend of Tarzan
# The Angry Birds Movie
# The Conjuring 2
# The Conjuring 2
# Arrival
# Passengers
# Sausage Party
# The Magnificent Seven
# Ride Along 2
# Miss Peregrine's Home for Peculiar Children
# The Accountant
# Teenage Mutant Ninja Turtles: Out of the Shadows
# Alice Through the Looking Glass
# Pete's Dragon
# The Girl on the Train
# Boo! A Madea Halloween
# Storks
# Lights Out
# London Has Fallen
# Miracles from Heaven
# Deepwater Horizon
# Why Him?
# My Big Fat Greek Wedding 2
# Me Before You
# The BFG
# Barbershop: The Next Cut
# Lion
# Manchester by the Sea
# Warcraft
# How to Be Single
# Mike and Dave Need Wedding Dates
# Almost Christmas
# Money Monster
# Allied
# Nerve
# The Nice Guys
# The Boy
# Dirty Grandpa
# Ouija: Origin of Evil
# Ouija: Origin of Evil
# The 5th Wave
# Inferno
# Mother's Day
# Patriots Day
# Gods of Egypt
# Hail, Caesar!
# When the Bough Breaks
# The Finest Hours
# Florence Foster Jenkins
# Hell or High Water
# The Forest
# Ben-Hur
# The Witch
# Bridget Jones's Baby
# What Now?
# Whiskey Tango Foxtrot
# Snowden
# Free State of Jones
# Free State of Jones
# Middle School: The Worst Years of My Life
# Nine Lives
# Nine Lives
# Race
# Bad Santa 2
# Masterminds
# Norm of the North
# The Birth of a Nation
# Eddie the Eagle
# A Beautiful Planet
# The Infiltrator
# Love & Friendship
# Triple 9
# Dangal
# Fifty Shades of Black
# Fifty Shades of Black
# No manches Frida
# Café Society
# Pride and Prejudice and Zombies
# The Darkness
# Nocturnal Animals
# The Perfect Match
# Popstar: Never Stop Never Stopping
# Hardcore Henry
# Meet the Blacks
# Ratchet & Clank
# Loving
# The Brothers Grimsby
# Southside with You
# Sultan
# Captain Fantastic
# Hunt for the Wilderpeople
# Incarnate
# Incarnate
# The Meddler2016 Re-release
# Swiss Army Man
# Denial
# Kabali
# Where to Invade Next
# Max Steel
# Batman: The Killing Joke
# Midnight Special
# Miss Sloane
# A Man Called Ove
# Indignation
# Everybody Wants Some!!
# Sing Street
# The Mermaid
# The Eagle Huntress
# Compadres
# The Other Side of the Door
# Anthropoid
# Ip Man 3
# Miles Ahead
# Kapoor & Sons
# Hillsong: Let Hope Rise
# Dear Zindagi
# Elle
# Fan
# Train to Busan
# Desierto
# Greater
# Demolition
# Purple Rain2016 Re-release
# M.S. Dhoni: The Untold Story
# To Joey, with Love
# Weiner
# Neerja
# Jane Got a Gun
# Priceless
# Julieta
# Toni Erdmann
# Genius
# The Little Prince
# The Little Prince
# The Neon Demon
# Embrace of the Serpent
# Housefull 3
# Lazer Team
# Vaxxed: From Cover-Up to Catastrophe
# Dough
# Wazir
# Papa Hemingway in Cuba
# The Insanity of God
# The Innocents
# Elvis & Nixon
# The Hollars
# Dark Horse2016 Re-release
# Neruda
# Gentleman
# Gentleman
# Her & Him
# Kapow
# The Wailing
# I Belonged to You
# Saturday's Warrior
# Chaar Sahibzaade 2: Rise of Banda Singh Bahadur
# Mr. Church
# American Honey
# El Jeremías
# Embrace: The Documentary
# Range 15
# The Bronze
# Tickled
# Lo and Behold: Reveries of the Connected World
# Gleason
# A Tale of Love and Darkness
# Teo-neol
# Knight of Cups
# Harry & Snowman
# Cold War II
# American Pastoral
# The Age of Shadows
# Befikre
# Luck-Key
# Only Yesterday2016 Re-release
# I Am Not Madame Bovary
# Mad Max: Fury Road2016 Re-release
# Things to Come
# The Wasted Times
# The Lobster
# Eat That Question
# Happy Bhaag Jayegi
# Kahaani 2
# High-Rise
# Kaashmora
# The Bounce Back
# AmeriGeddon
# Francofonia
# Ixcanul
# Aquarius
# My Golden Days
# The Family Fang
# Dheepan
# Yo-kai Watch Movie: It's the Secret of Birth, Meow!
# Oasis: Supersonic
# Jimmy Vestvood: Amerikan Hero
# The Love Witch
# Tampopo
# Spirit of the Game
# Spirit of the Game
# Naam Hai Akira
# SEED: The Untold Story
# Kaptaan
# The Clan
# The Fallen Idol2016 Re-release
# Digimon Adventure tri. Part 1: ReunionDomestic Release
# The Masked Saint
# League of Gods
# The Wave
# Asura
# Hieronymus Bosch, Touched by the Devil
# Apparition Hill
# The Fits
# De Palma
# Eva Hesse
# Born to Be Blue
# Generation Found
# Kicks
# Seasons
# Rams
# Michael Moore in TrumpLand
# Psycho-Pass: The Movie
# The Kind Words
# Ism
# Ism
# Dawson City: Frozen Time
# Requiem for the American Dream
# Requiem for the American Dream
# The Brand New Testament
# Chimes at Midnight
# Spirits' Homecoming
# A War
# Fire at Sea
# Remember the Goal
# Tale of Tales
# Victor
# The Measure of a Man
# Elevator to the Gallows2016 Re-release
# Aferim!
# Until Forever2016 Re-release
# Under the Sun
# Dictator
# Demon
# Puerto Ricans in Paris
# Cameraperson
# Tower
# Our Last Tango
# Rock on 2
# The Fight Within
# Other People
# Morris from America
# Fireworks Wednesday2016 Re-release
# Author: The JT LeRoy Story
# Los Sures
# Cock and Bull
# A Street Cat Named Bob
# Vita Activa: The Spirit of Hannah Arendt
# For the Love of Spock
# My Best Friend's Wedding
# My Best Friend's Wedding
# Colliding Dreams
# Don't Blink
# Don't Blink
# Sword Master
# Les Cowboys
# Dancer
# The Congressman
# Norman Lear: Just Another Version of You
# The Dark Horse
# Tamjung Hong Gil-dong: Sarajin Ma-eul
# Tamjung Hong Gil-dong: Sarajin Ma-eul
# Max Rose
# Ran2016 Re-release
# Trapped
# Creative Control
# Mifune: The Last Samurai
# Too Late
# Presenting Princess Shaw
# Time Renegades
# Time Renegades
# Command and Control
# The Battle of Algiers2016 Re-release
# Wedding Doll
# Wedding Doll
# L'attesa
# Regression
# High Strung
# The Last Man on the Moon
# Cemetery of Splendor
# Disorder
# The Take
# In Order of Disappearance2016 Re-release
# The Treasure
# Tanna
# Tanna
# 3 Weeks in Yerevan
# We Are X
# A Melody to Remember
# Nuts!
# Danny Says
# Phantom of the Theatre
# The Land
# Closet Monster
# Wild Oats
# The Homeless Billionaire
# Restored Me
# Catching the Sun
# Spa Night
# Germans & Jews
# Band of Outsiders2016 Re-release
# Come What May
# How to Let Go of the World: and Love All the Things Climate Can't Change
# How to Let Go of the World: and Love All the Things Climate Can't Change
# Kill Me, Deadly
# Until Forever
# Mr. Right
# Off the Rails
# Last Cab to Darwin
# The Map Against the World
# Equals
# Multiple Maniacs
# No Home Movie
# Rurouni Kenshin Part I: Origins2016 Re-release
# Kaili Blues
# Anesthesia
# As I Open My Eyes
# As I Open My Eyes
# Being Charlie
# For a Few Bullets
# The Seventh Fire
# The Best Democracy Money Can Buy
# The Dog Wedding
# The Last Princess
# The Last Princess
# Valley of Love
# The Seasons In Quincy: Four Portraits of John Berger
# Unlocking the Cage
# The Eyes of My Mother
# Neon Bull
# Papa
# Front Cover
# Standing Tall
# Cosmos
# Chevalier
# Gurukulam
# Banjo
# The New Year's Eve of Old Lee
# Disturbing the Peace
# Évolution
# Lolo
# The Fiancé
# Southbound
# Harmony
# Harmony
# Goat
# Be Here Now
# Reparation
# Sanam Teri Kasam
# Blue Jay
# Thank You for Your Service
# Thank You for Your Service
# Term Life
# Already Tomorrow in Hong Kong
# Time Changer2016 Re-release
# Band of Robbers
# This Last Lonely Place
# The Sea of Trees
# Never
# No Pay, Nudity
# Art Bastard
# Art Bastard
# Revelation: Dawn of Global Government
# Ktown Cowboys
# Ktown Cowboys
# Seoul Searching
# The Lion in Winter2016 Re-release
# Coming Through the Rye
# Peter and the Farm
# A Bit of Bad Luck
# Holy Hell
# I Knew Her Well
# Men Go to Battle
# Streit's: Matzo and the American Dream
# Landfill Harmonic
# Always Shine
# On the Map
# Tharlo
# Tharlo
# Colonia
# Be Somebody
# Starcrossed
# Argentina
# Lamb
# The Wanderers2016 Re-release
# The Uncondemned
# A Perfect Day
# Yosemite
# Yosemite
# A Space Program
# Spices of Liberty
# The Duelist
# Neither Heaven Nor Earth
# The Monster
# City of Women
# Elstree 1976
# Hot Water
# Hot Water
# When Two Worlds Collide
# Lucha Mexico
# River of Grass
# The Ruins of Lifta
# Hacker
# Approaching the Unknown
# Beta Test
# Into the Forest
# The Lost Arcade
# Frank & Lola
# The Last King
# Providence
# Mojave
# Golden Kingdom
# Golden Kingdom
# The Other Side
# Pet
# Roseanne for President!
# Portrait of a Garden
# I Don't Belong Anywhere: The Cinema of Chantal Akerman
# Indian Point
# It Had to Be You
# Boom Bust Boom
# Mad Tiger
# Ghost Team
# The Charnel House
# The Carer
# The Carer
# Welcome to Happiness
# Call Her Applebroog
# Call Her Applebroog
# Marinoni: The Fire in the Frame
# Sworn Virgin
# The Automatic Hate
# The Automatic Hate
# Search Party2016 Re-release
# Maximum Ride
# Breaking a Monster
# Among the Believers
# The Hollow
# The Loving Story2016 Re-release
# Restored Me2016 Re-release
# Burning Bodhi
# A Kind of Murder
# White Lies2016 Re-release
# Homeland (Iraq Year Zero)
# Ek Hazarachi Note
# Memoria
# The Watermelon Woman
# A Beautiful Now
# Miss India America
# Level Up
# Hyena Road
# Next Time I'll Aim for the Heart
# A Girl Like Grace
# Down by Love
# The Pit
# Green is Gold
# Hannah: Buddhism's Untold Journey
# News from Planet Mars
# Satanic
# Star Wars: Episode VIII - The Last Jedi
# Wonder Woman
# Jumanji: Welcome to the Jungle
# It
# Despicable Me 3
# Despicable Me 3
# Justice League
# The Fate of the Furious
# Coco
# Dunkirk
# Get Out
# The Lego Batman Movie
# Kong: Skull Island
# Cars 3
# Split
# Transformers: The Last Knight
# Girls Trip
# Pitch Perfect 3
# Daddy's Home 2
# Murder on the Orient Express
# Kingsman: The Golden Circle
# Blade Runner 2049
# John Wick: Chapter 2
# The Emoji Movie
# Power Rangers
# Ferdinand
# The Mummy
# The Hitman's Bodyguard
# Alien: Covenant
# Captain Underpants: The First Epic Movie
# A Bad Moms Christmas
# A Bad Moms Christmas
# The Shape of Water
# Baywatch
# The Shack
# American Made
# The Dark Tower
# Lady Bird
# Lady Bird
# The Great Wall
# Smurfs: The Lost Village
# xXx: Return of Xander Cage
# 47 Meters Down
# Valerian and the City of a Thousand Planets
# The Star
# Ghost in the Shell
# Ghost in the Shell
# King Arthur: Legend of the Sword
# Jigsaw
# Jigsaw
# American Assassin
# The Foreigner
# Everything, Everything
# Wind River
# Monster Trucks
# Fist Fight
# Life
# I, Tonya
# Molly's Game
# The Nut Job 2: Nutty by Nature
# Rings
# Logan Lucky
# Resident Evil: The Final Chapter
# All the Money in the World
# Gifted
# Gifted
# Downsizing
# The Bye Bye Man
# Victoria & Abdul
# Rough Night
# The Disaster Artist
# The Disaster Artist
# Sleepless
# Diary of a Wimpy Kid: The Long Haul
# The Circle
# Baahubali 2: The Conclusion
# Baahubali 2: The Conclusion
# Chips
# Only the Brave
# Call Me by Your Name
# The Zookeeper's Wife
# Father Figures
# The Glass Castle
# Flatliners
# Detroit
# The Case for Christ
# Wish Upon
# It Comes at Night
# Born in China
# Unforgettable
# The Beguiled
# Marshall
# Marshall
# A Cure for Wellness
# The Space Between Us
# Gold
# I Am Not Your Negro
# Beatriz at Dinner
# Birth of the Dragon
# Loving Vincent
# Same Kind of Different as Me
# Lowriders
# Just Getting Started
# The Florida Project
# Paris Can Wait
# Tiger Zinda Hai
# Tiger Zinda Hai
# Your Name.
# Your Name.
# The Book of Henry
# The Hero
# Norman
# Table 19
# An Inconvenient Sequel: Truth to Power
# Raees
# The Leisure Seeker
# Close Encounters of the Third Kind2017 Re-release
# Colossal
# Ingrid Goes West
# Leap!
# The Oscar Nominated Short Films 2017: Live Action
# Kedi
# Wolf Warrior 2
# My Cousin Rachel
# My Cousin Rachel
# Showtime Championship Boxing: Floyd Mayweather vs. Conor McGregor
# Is Genesis History?
# IN OUR HANDS: Battle for Jerusalem
# LBJ
# T2 Trainspotting
# Jeepers Creepers III
# The Resurrection of Gavin Stone
# Collide
# The Lovers
# Brad's Status
# Good Time
# Badrinath Ki Dulhania
# Toilet: A Love Story
# Free Fire
# The Last Word
# Goodbye Christopher Robin
# Jane
# Menashe
# Dunkirk2017 Re-release
# Slamma Jamma
# When Harry Met Sejal
# Jolly LLB 2
# A Ghost Story
# Professor Marston & the Wonder Women
# The Stray
# A Taxi Driver
# The Square
# Mully
# Twins 2
# The Wedding Plan
# Wonder Wheel
# The Sense of an Ending
# 3 idiotas
# True to the Game
# Steve McQueen: American Icon
# Spirited Away2017 Re-release
# The Trip to Spain
# Viceroy's House
# The Battleship Island
# Wonderstruck
# Terminator 2: Judgment Day2017 Re-release
# Casablanca2017 Re-release
# Columbus
# Last Flag Flying
# Lucky
# Tubelight
# Journey to the West: The Demons Strike Back
# Journey to the West: The Demons Strike Back
# The Polar Express2017 IMAX Release
# Detective Jagga
# The Ex-File 3: The Return of The Exes
# The Ex-File 3: The Return of The Exes
# Patti Cake$
# George Takei's Allegiance
# George Takei's Allegiance
# Mark Felt: The Man Who Brought Down the White House
# Mubarakan
# Walk With Me
# May It Last
# Revive Us 2
# Countdown to Canelo vs. Golovkin
# Titanic2017 Re-release
# The Devotion of Suspect X
# Neither Wolf Nor Dog
# The Midwife
# Battle of Memories
# Battle of Memories
# Novitiate
# Bitter Harvest
# Samaritan's Purse presents Facing Darkness
# Samaritan's Purse presents Facing Darkness
# Dolores
# Dolores
# Brigsby Bear
# Brigsby Bear
# Fairy Tail: Dragon Cry
# Once Upon A Time
# Confidential Assignment
# DCI 2017 Tour Premeire
# Phillauri
# Chasing the Dragon
# Sailor Moon R: The Movie: The Promise of the Rose
# Song to Song
# One Piece Film: Gold
# Love, Kennedy
# Tom of Finland
# Kung Fu Yoga
# Long Strange Trip - The Untold Story of The Grateful Dead
# Pearl Jam: Let's Play Two
# This Is Not What I Expected
# God's Own Country
# In the Fade
# Chuck
# Obit.
# Citizen Jane: Battle for the City
# The Breadwinner
# My Life as a Zucchini
# Happy End
# Ittefaq
# Buddies in India
# Buddies in India
# Stalker
# Wakefield
# Cezanne et Moi
# The Fortress
# Gook
# Gook
# Government 3
# Band Aid
# The Ottoman Lieutenant
# Crown Heights
# American Satan
# Little Shop of Horrors2017 Re-release
# Jeremiah Tower: The Last Magnificent
# Rumble: The Indians Who Rocked The World
# California Typewriter
# Big Sonia
# Truman
# Donnie Darko2016 Re-release
# The Prison
# Risk
# Spark: A Space Tail
# The Bad Batch
# Marjorie Prime
# Marjorie Prime
# Past Life
# Take Every Wave: The Life of Laird Hamilton
# Mr. Gaga: A True Story of Love and Dance
# In This Corner of the World
# In This Corner of the World
# David Lynch: The Art Life
# 9/11
# Valley of Bones
# Polina, danser sa vie
# 13 Minutes
# Manifesto
# Ex Libris: New York Public Library
# 3 Generations
# The Journey
# The Void
# The Unknown Girl
# Blade of the Immortal
# Chavela
# Chavela
# Thelma
# The Last Dalai Lama?
# Lupin the 3rd: Castle of Cagliostro2017 Re-release
# Moka
# City of Ghosts
# The B-Side: Elsa Dorfman's Portrait Photography
# Buena Vista Social Club: Adios
# The Thousand Faces of Dunjia
# Our Time Will Come
# We Love You, Sally Carmichael!
# The King's Choice
# The King's Choice
# Slack Bay
# The Trouble with Terkel
# Like Crazy
# Fabricated City
# Fabricated City
# The Lure
# Score
# Some Like It Hot
# Munna Michael
# Munna Michael
# Aida's Secrets
# Tim Timmerman: Hope of America
# The Mayor2017 Re-release
# The Fencer2016 Re-release
# Keep Watching
# Because of Grácia
# Stefan Zweig: Farewell to Europe
# Harold and Lillian: A Hollywood Love Story
# Pop Aye
# Pop Aye
# Bill Nye: Science Guy
# Wait for Your Laugh
# Buster's Mal Heart
# Turn It Around: The Story of East Bay Punk
# My Entire High School Sinking Into the Sea
# Architects of Denial
# The Teacher
# I Can Speak
# Donald Cried
# Worlds Apart
# Just One Drop
# The Force
# Bang! The Bert Berns Story
# The Boom
# The Paris Opera
# The Paris Opera
# God of War
# Beautiful Accident
# Tickling Giants
# The Ornithologist
# Person to Person
# Napping Princess
# Saving Banksy
# Quest
# So B. It
# Panique
# Maurice2017 Re-release
# Maurice2017 Re-release
# The Death of Louis XIV
# The Settlers
# Karl Marx City
# Karl Marx City
# Unrest
# Birdboy: The Forgotten Children
# The Commune
# I Am the Blues
# A Woman's Life
# On the Beach at Night Alone
# Heart Blackened
# Growing Up Smith
# Rat Film
# Afterimage
# Love & Taxes
# Super Dark Times
# Spettacolo
# Spettacolo
# Brimstone & Glory
# Signature Move
# Sidemen: Long Road to Glory
# 7 Witches
# XX
# The Wound
# Dealt
# No Greater Love
# In Pursuit of Silence
# Uncertain
# Lemon
# Ribbons
# 30 Years of Garbage: The Garbage Pail Kids Story
# The Untamed
# Bronx Gothic
# Mali Blues
# The Daughter
# The Lucky Man
# The Departure
# Naples '44
# Jasmine
# Simple Creature
# Finding Oscar
# The Grace of Jake
# The Grace of Jake
# The Recall
# My Scientology Movie
# My Scientology Movie
# Paradise Club
# Bending the Arc
# The Passion of Joan of Arc
# Trophy
# God Knows Where I Am
# Massacre on Aisle 12
# A Beginner's Guide to Snuff
# All These Sleepless Nights
# The Blackcoat's Daughter
# RV: Resurrected Victims
# Better Watch Out
# Koroshiya 12017 Re-release
# Heat and Dust2017 Re-release
# BOSTON: An American Running Story2017 Re-release
# BOSTON: An American Running Story2017 Re-release
# Hare Krishna! The Mantra, the Movement and the Swami Who Started It2017 Re-release
# That Most Important Thing: Love
# Carrie Pilby
# Carrie Pilby
# Bobbi Jene
# Glory
# The Last Shaman
# Bad Grandmas
# Bad Grandmas
# Food Evolution
# Brave New Jersey
# 33 & Beyond: The Royal Art of Freemasonry
# Mission Control: The Unsung Heroes of Apollo
# Song Of Granite
# All the Queen's Horses
# Charged: The Eduardo Garcia Story
# Charged: The Eduardo Garcia Story
# Kills On Wheels2016 Re-release
# SHOT! The Psycho-Spiritual Mantra of Rock
# Vince Giordano: There's a Future in the Past
# The Farthest
# The Farthest
# Last Men in Aleppo
# Antarctica: Ice and Sky2017 Re-release
# After Love
# Red Trees
# Legend of the Naga Pearls
# Intent to Destroy: Death, Denial & Depiction
# Junction 48
# In Search of Fellini
# Heal
# Blind
# Félicité
# Seven Beauties
# 4 Days in France
# Staying Vertical
# Frank Serpico
# Sweet Virginia
# The Tribes of Palos Verdes
# Dead Awake
# Beside Bowie: The Mick Ronson Story
# Saigon Bodyguards
# Clarence
# Amelia 2.0
# Pelle the Conqueror2017 Re-release
# Machines
# Living Proof
# Miss Kiet's Children2017 Re-release
# Lycan
# The Eyes
# The Eyes
# Julian Schnabel: A Private Portrait
# Amnesia
# Irreplaceable
# We Are the Flesh
# Natasha
# Mr. Chibbs
# Served Like a Girl
# Anatahan
# Overdrive
# The Wrong Light
# Big Time
# Big Time
# The Jazz Funeral
# The Dark Below
# Suntan
# Scum
# In the Steps of Trisha Brown
# On Wings of Eagles2017 Re-release
# On Wings of Eagles2017 Re-release
# Starless Dreams
# Starless Dreams
# Tad the Lost Explorer and the Secret of King Midas
# The Work
# The Vault
# Trespass Against Us
# Gold
# The Reagan Show
# The Man from Earth: Holocene
# Reset
# Bad Lucky Goat
# Tournament
# I Love You Both
# A Boy Called Po
# 30-LOVE
# My Father Die
# Badsville
# Emily
# Dream Boat
# The Woman Who Left
# The Gender Card Flip
# Bugs
# Soul on a String
# Dalida
# Speed Sisters
# Planetarium
# Justice
# Heal the Living
# Kepler's Dream
# Demons
# 1898: Our Last Men in the Philippines
# I Dream in Another Language
# Daughter of the Nile
# Miles
# 7 from Etheria
# Dayveon
# The Ghoul
# Almost Friends
# The Outcasts
# The Forest for the Trees
# It's Not Yet Dark
# The Penguin Counters
# Extraordinary Ordinary People
# Amityville: The Awakening
# Black Panther
# Avengers: Infinity War
# The Grinch
# The Grinch
# Bohemian Rhapsody
# Bohemian Rhapsody
# A Star Is Born
# Solo: A Star Wars Story
# Venom
# Ralph Breaks the Internet
# Spider-Man: Into the Spider-Verse
# Crazy Rich Asians
# Hotel Transylvania 3: Summer Vacation
# Fantastic Beasts: The Crimes of Grindelwald
# Ready Player One
# Bumblebee
# Mamma Mia! Here We Go Again
# The Nun
# Creed II
# Peter Rabbit
# The Equalizer 2
# Rampage
# A Wrinkle in Time
# Fifty Shades Freed
# Fifty Shades Freed
# Christopher Robin
# Green Book
# Green Book
# I Can Only Imagine
# Smallfoot
# The First Purge
# Book Club
# The House with a Clock in Its Walls
# Instant Family
# Blockers
# Pacific Rim: Uprising
# Tomb Raider
# Maze Runner: The Death Cure
# The Nutcracker and the Four Realms
# Tag
# A Simple Favor
# The Predator
# Sicario: Day of the Soldado
# BlacKkKlansman
# I Feel Pretty
# Vice
# Breaking In
# Goosebumps 2: Haunted Halloween
# 12 Strong
# Den of Thieves
# First Man
# First Man
# Sherlock Gnomes
# Widows
# Truth or Dare
# Love, Simon
# Second Act
# The Commuter
# The Commuter
# The 15:17 to Paris
# Mile 22
# Alpha
# Alpha
# Peppermint
# The Favourite
# Death Wish
# The Spy Who Dumped Me
# The Spy Who Dumped Me
# Annihilation
# Isle of Dogs
# Nobody's Fool
# Adrift
# Super Troopers 2
# Holmes & Watson
# Teen Titans GO! To the Movies
# Searching
# Searching
# Winchester
# The Strangers: Prey at Night
# White Boy Rick
# White Boy Rick
# Won't You Be My Neighbor?
# Proud Mary
# The Happytime Murders
# Show Dogs
# Bad Times at the El Royale
# Free Solo
# Sorry to Bother You
# Chappaquiddick
# Chappaquiddick
# Mary Queen of Scots
# The Girl in the Spider's Web
# The Possession of Hannah Grace
# RBG
# The Darkest Minds
# Three Identical Strangers
# Padmaavat
# The Old Man & the Gun
# The Miracle Season
# The Miracle Season
# Midnight Sun
# Traffik
# Can You Ever Forgive Me?
# Early Man
# Unsane
# Dog Days
# Boy Erased
# Fahrenheit 11/9
# Unbroken: Path to Redemption
# The Hurricane Heist
# Every Day
# Once Upon a Deadpool2018 Re-release
# God's Not Dead: A Light in Darkness
# Kin
# Stan & Ollie
# Colette
# Simmba
# Action Point
# Gringo
# Samson
# Cold War2018 Re-release
# Johnny English Strikes Again
# Gotti
# Burn the Stage: The Movie
# Ya veremos
# 2.0
# 2.0
# Life Itself
# Life Itself
# Sgt. Stubby: An American Hero
# Indivisible
# The Oscar Nominated Short Films 2018: Live Action
# Disobedience
# First Reformed
# Juliet, Naked
# Juliet, Naked
# 2001: A Space Odyssey2018 Re-release
# The Sisters Brothers
# Made for More
# American Animals
# God Bless the Broken Road
# Bharath Ane Nenu
# Qué León
# You Were Never Really Here
# Mary and the Witch's Flower
# Hearts Beat Loud
# 1991
# Papillon
# At Eternity's Gate
# The Fall of the American Empire
# Puzzle
# Great Performances at the Met: Puccini: Tosca
# Great Performances at the Met: Puccini: Tosca
# A Fantastic Woman
# Pope Francis: A Man of His Word
# Assassination Nation
# The Front Runner
# Great Performances at the Met: Verdi: La Traviata
# Racetime
# Racetime
# Moses
# Race 3
# Capernaum
# Great Performances at the Met: Verdi: Aida
# The Bookshop
# Destroyer
# Thugs of Hindostan
# Don't Worry, He Won't Get Far on Foot
# Princess Mononoke2018 Re-release
# Princess Mononoke2018 Re-release
# Finding Your Feet
# Baaghi 2
# McQueen
# The Seagull
# Great Performances at the Met: Massenet: Cendrillon
# Mandy
# Grease2018 Re-release
# Beautifully Broken
# An Interview with God
# Along With the Gods: The Last 49 Days
# Andhadhun
# Great Performances at the Met: Verdi: Luisa Miller
# Lean on Pete
# Lean on Pete
# The Dark Crystal2018 Re-release
# Zero
# Elvis: The Comeback Special
# Raid
# Raid
# The Insult
# Labyrinth2018 Re-release
# Little Italy
# The Dawn Wall2018 Re-release
# The Miseducation of Cameron Post
# Let the Sunshine In
# Tea With the Dames
# The Cakemaker
# Great Performances at the Met: Nico Muhly: Marnie
# BANDSTAND: The Broadway Musical on Screen
# BANDSTAND: The Broadway Musical on Screen
# Schindler's List2018 Re-release
# Like Arrows
# Mirai
# Beast
# Made in India
# Pokémon the Movie: The Power of Us
# Border
# How Long Will I Love U
# The Polar Express2018 Re-release
# Vox Lux
# The Catcher Was a Spy
# Burning
# The Little Stranger
# Blaze
# Boundaries
# The Island
# Dragon Ball Z: Broly - The Legendary Super Saiyan
# Ponyo2018 Re-release
# Lizzie
# Love, Gilda
# Foxtrot
# The Sound of Music2018 Re-release
# DCI 2019: Big, Loud & Live 16
# The Grateful Dead Meet-Up 2018
# The Big Lebowski2018 Re-release
# Pick of the Litter
# Husband Material
# Loveless
# The Cat Returns2018 Re-release
# The Children Act
# Castle in the Sky2018 Re-release
# The Sandlot2018 Re-release
# Bullitt2018 Re-release
# Bullitt2018 Re-release
# Monsters and Men
# Bilal: A New Breed of Hero2018 Re-release
# The Happy Prince
# Final Portrait
# Final Portrait
# Scotty and the Secret History of Hollywood
# Condorito: The Movie
# Frankenstein2018 Re-release
# Frankenstein2018 Re-release
# A Bag of Marbles
# The Night Is Short, Walk on Girl
# The Philadelphia Story2018 Re-release
# West Side Story2018 Re-release
# Space Mutiny
# Krull2018 Re-release
# Vertigo2018 Re-release
# Vertigo2018 Re-release
# Soorma
# Oh Lucy!
# Grace Jones: Bloodlight and Bami
# Jurassic Park2018 Re-release
# Mountain
# Kusama: Infinity
# Suicide the Ripple Effect
# Russ Taff: I Still Believe
# Shine
# Hichki
# Flower
# The Bolshoi Ballet: Live From Moscow - The Nutcracker
# The Opera House
# The Riot and the Dance
# The Bolshoi Ballet: Live From Moscow - Romeo and Juliet
# Great Performances at the Met: MET Opera: Magic Flute
# Showtime Championship Boxing: Deontay Wilder vs. Tyson Fury
# The Bolshoi Ballet: Live From Moscow - Giselle
# Sunset Blvd.2018 Re-release
# More Than Funny
# Son of Bigfoot
# Disney's Newsies: The Broadway Musical!2018 Re-release
# Science Fair
# Kings
# Kings
# The Endless
# The World Before Your Feet
# The World Before Your Feet
# Detective Dee: The Four Heavenly Kings
# Detective Dee: The Four Heavenly Kings
# Eating You Alive
# Across the Universe2018 Re-release
# Big2018 Re-release
# Best F(r)iends: Volume 1
# Batti Gul Meter Chalu
# Skate Kitchen
# Hamlet2018 Re-release
# Superman2018 Re-release
# Bishôjo senshi Sailor Moon Super S Special
# Borg vs. McEnroe
# Matangi/Maya/M.I.A
# MFKZ
# Agent Mr. Chan
# Heading Home: The Tale of Team Israel
# The Guilty
# Default
# Zama
# Gauguin: Voyage to Tahiti
# Rebel Without a Cause2018 Re-release
# The Final Year
# The Monkey King 3
# Maquia: When the Promised Flower Blooms
# National Theatre Live: King Lear
# Karwaan
# The Accidental Detective 2: In Action
# BuyBust
# BuyBust
# The Guardians
# The Guardians
# The Bolshoi Ballet: Live From Moscow - The Flames of Paris
# Great Performances at the Met: Puccini: Turandot
# The Bolshoi Ballet: Live From Moscow - La Sylphide
# The Bolshoi Ballet: Live From Moscow - The Lady of the Camellias
# Is Genesis History?2018 Re-release
# Boom for Real: The Late Teenage Years of Jean-Michel Basquiat
# Far From the Tree
# Silencio
# The Last Resort
# Buttons, A New Musical Film
# Ghost Stories
# The Little Mermaid
# Great Performances at the Met: Puccini: Madama Butterfly
# Great Performances at the Met: Tchaikovsky: Eugene Onegin2018 Re-release
# Support the Girls
# Support the Girls
# Sleepless in Seattle2018 Re-release
# Sleepless in Seattle2018 Re-release
# The Young Karl Marx
# Bel Canto
# '85: The Greatest Team in Football History
# Becoming Astrid
# Becoming Astrid
# Five Seasons: The Gardens of Piet Oudolf
# Till The End Of The World
# Till The End Of The World
# The Great Buster
# George Takei's Allegiance2018 Re-release
# Gonjiam: Haunted Asylum
# Mantra: Sounds Into Silence
# Bodied
# Take Point
# Hale County This Morning, This Evening
# The Dawn Wall
# A Chance in the World
# A Chance in the World
# The Negotiation
# El Angel
# El Angel
# The Captain
# Mary Shelley
# National Theatre Live: Julius Caesar
# Airpocalypse
# Never Heard
# Memoir of War
# Happy Phirr Bhag Jayegi
# Filmworker
# Ismael's Ghosts
# Revenge
# Andrei Rublev2018 Re-release
# All About Nina
# Meow Wolf: Origin Story
# National Theatre Live: Macbeth
# Godspeed: The Race Across America
# Reign of Judges: Title of Liberty - Concept Short
# BANDSTAND: The Broadway Musical on Screen2018 Re-release
# John McEnroe: In the Realm of Perfection
# Running for Grace
# Cat on a Hot Tin Roof
# The Third Murder
# Goldstone2018 Re-release
# The Price of Everything
# Lobster Cop
# National Theatre Live: Antony & Cleopatra
# National Theatre Live: Antony & Cleopatra
# Blood Fest
# Doctor Who: The Woman Who Fell to Earth
# Nancy
# En el séptimo día
# The Boxcar Children - Surprise Island
# 93Queen
# The Brawler
# Keys To The Heart
# Tehran Taboo
# Above and Beyond: NASA's Journey to Tomorrow
# Bye Bye Germany
# Helicopter Eela
# Namiya
# The Fog2018 Re-release
# Wastelander
# Chef Flynn
# Where Hands Touch
# Under the Tree
# Making the Five Heartbeats
# The Doctor from India
# 3100, Run and Become
# Beuys
# Feng Shui
# Never Goin' Back
# Viper Club
# Where Is Kyra?
# Where Is Kyra?
# Horn from the Heart: The Paul Butterfield Story
# Cynthia
# Woman Walks Ahead
# Black '47
# Bhavesh Joshi Superhero
# Django
# American Dream: Detroit
# Digimon Adventure tri. Part 6: Future
# The Great Silence
# Twiceland
# Digimon Adventure tri. Part 5: Coexistence
# Before We Vanish
# The Royal Wedding: Prince Harry and Meghan Markle
# Hal
# The China Hustle
# 350 Days - Legends. Champions. Survivors
# Bigger
# Summer in the Forest
# Rodin
# Liyana
# Garry Winogrand: All Things are Photographable
# Hitler's Hollywood
# First We Take Brooklyn
# Golden Exits
# Golden Exits
# Western
# Humor Me
# Submission
# Divide and Conquer
# Araby
# Gray Matter
# Oolong Courtyard: KungFu School
# Krystal
# Girls vs Gangsters
# Return of the Hero
# Breath
# Small Group
# Searching for Ingmar Bergman
# Mind Game
# For Those Who Don't Read Me
# The House of Tomorrow
# The House of Tomorrow
# The Big Bad Fox and Other Tales
# The Road Movie
# PGS: Intuition Is Your Personal Guidance System
# That Summer
# 24 Frames
# Holy Hell
# Maui
# Sollers Point
# Poor Boy
# The Desert Bride
# The Mercy2018 Re-release
# On Her Shoulders
# Quai des Orfèvres2018 Re-release
# Senso
# The Cured
# The Cured
# Milford Graves Full Mantis
# Belle de Jour2017 Re-release
# The Charmer
# Jet Trash2018 Re-release
# No Intenso Agora
# An Elephant's Journey
# Swimming with Men
# Life and Nothing More
# Elliot the Littlest Reindeer
# Vazante
# Letter from Masanjia
# Letter from Masanjia
# The Atomic Cafe
# The Judge
# Loving Pablo
# The Female Brain
# A Paris Education
# Half the Picture
# Primal Rage: The Legend of Konga
# Tyrel
# Ganja & Hess
# Did You Wonder Who Fired the Gun?
# The Tag Along: Devil Fish
# The Tag Along: Devil Fish
# Ice Dragon: Legend of the Blue Daisies
# The Devil and Father Amorth
# Izzy Gets the F*ck Across Town
# Apocalypsis
# Freak Show
# November
# November
# Anything
# Crime + Punishment
# Allegiance to Broadway
# Desolation
# Gabriel and the Mountain
# Marlina the Murderer in Four Acts
# King of Hearts
# Revival
# Bob le Flambeur
# When You Read This Letter
# Narcissister Organ Player
# Sicilian Ghost Story
# Trust Machine: The Story of Blockchain
# A Prayer Before Dawn
# The Last Movie Star
# Chasing the Blues
# The Escape
# Weed the People
# Here and Now
# The Boy Downstairs
# Un traductor
# Un traductor
# Shed Skin Papa
# Our Blood is Wine
# Like Me
# How Viktor 'The Garlic' Took Alexey 'The Stud' to the Nursing Home
# American Socialist: The Life and Times of Eugene Victor Debs
# American Chaos
# Head Full of Honey
# The Most Unknown
# Les Parents Terribles
# Summer '03
# Hannah
# The Public Image is Rotten
# The Assassin's Code
# Wedding Party 2
# Class Rank
# The Advocates
# Around India with a Movie Camera
# Heavy Trip
# Furious
# River Runs Red
# Please Stand By
# The Quest of Alain Ducasse
# El Mar La Mar
# Zoo Wars
# Summer of '67
# Beauty and the Dogs
# Colossal Youth
# The Clovehitch Killer
# Legend of the Mountain
# The Lodgers
# This is Congo
# In the Land of Pomegranates
# Duck Butter
# Calling All Earthlings
# A Whale of a Tale
# An Evening with Beverly Luff Linn
# School of Life
# One Last Thing
# I Am MLK Jr.
# Are We Not Cats
# Cuban Food Stories
# Postcards from London
# In Searching
# 12 Days
# 12 Days
# The Texture of Falling
# Social Animals
# An L.A. Minute
# An L.A. Minute
# Edward II2018 Re-release
# Status Update
# The Other Side of Everything
# Kangaroo
# Kickboxer: Retaliation
# Weightless
# The Peacemaker
# Stella's Last Weekend
# Armed
# Cocote
# Nelly
# The Family
# Fourplay
# Under The Wire
# The Cage Fighter
# At First Light
# Over the Limit
# Game Changers
# Game Changers
# Hot to Trot
# The Pact
# 10x10
# West Of The Jordan River
# Finding Happiness
# An Actor Prepares
# Henchmen
# That Way Madness Lies...
# Marrowbone
# Beauty and the Beholder
# I Still See You
# Guy
# Altered Perception
# Two Men Went to War2018 Re-release
# Invisible Hands
# The Breadwinner2018 Re-release
# TVTV: Video Revolutionaries
# Higher Power
# Frozen II
# Toy Story 4
# Spider-Man: Far from Home
# Aladdin
# Joker
# Jumanji: The Next Level
# It Chapter Two
# Us
# Fast & Furious Presents: Hobbs & Shaw
# Pokémon Detective Pikachu
# Shazam!
# Ford v Ferrari
# Dumbo
# Maleficent: Mistress of Evil
# The LEGO Movie 2: The Second Part
# Hustlers
# The Addams Family
# Yesterday
# Zombieland: Double Tap
# Scary Stories to Tell in the Dark
# X-Men: Dark Phoenix
# Terminator: Dark Fate
# A Beautiful Day in the Neighborhood
# Dora and the Lost City of Gold
# Escape Room
# Escape Room
# The Curse of la Llorona
# Uncut Gems
# Isn't It Romantic
# Gemini Man
# Wonder Park
# Playing with Fire
# Harriet
# Breakthrough
# Crawl
# Just Mercy
# The Intruder
# The Hustle
# Overcomer
# Cold Pursuit
# Doctor Sleep
# Dragon Ball Super: Broly
# Long Shot
# Child's Play
# Happy Death Day 2U
# Countdown
# Judy
# Judy
# A Dog's Journey
# Booksmart
# Stuber
# 47 Meters Down: Uncaged
# Black and Blue
# The Peanut Butter Falcon
# UglyDolls
# UglyDolls
# Charlie's Angels
# The Good Liar
# The Kid Who Would Be King
# Missing Link
# The Kitchen
# After
# Blinded by the Light
# Dark Waters
# The Lighthouse
# Greta
# The Best of Enemies
# No Manches Frida 2
# Serenity
# Penguins
# The Dead Don't Die
# The Dead Don't Die
# Jexi
# Run the Race
# The Wandering Earth
# Captive State
# Arctic Dogs
# Gully Boy
# The Goldfinch
# The Goldfinch
# Bring the Soul: The Movie
# Menteur
# Pavarotti
# Pain and Glory
# Brian Banks
# Uri: The Surgical Strike
# Ip Man 4: The Finale
# Ne Zha
# The Oscar Nominated Short Films 2019: Documentary
# BTS World Tour: Love Yourself in Seoul
# The Beach Bum
# Maiden
# Honey Boy
# Friends 25th: The One With The Anniversary
# Saaho
# Everybody Knows
# The Art of Self-Defense
# Arctic2019 Re-release
# Promare
# Super 30
# Gone with the Wind2019 Re-release
# 3 from Hell
# Total Dhamaal
# Official Secrets
# Official Secrets
# Better Days
# Fantastic Fungi
# A Hidden Life
# Wild Rose
# Extreme Job
# The Kid
# El Chicano
# Pilgrim's Progress
# Pilgrim's Progress
# Metallica & San Francisco Symphony - S&M2
# BTS World Tour 'Love Yourself: Speak Yourself' (The Final) Seoul Live Viewing
# High Life
# Ek Ladki Ko Dekha Toh Aisa Laga
# Konosuba!: God's Blessing on This Wonderful World! - Legend of Crimson
# Playmobil: The Movie
# My Neighbor Totoro2019 Re-release
# El Coyote
# The Song of Names
# Bennett's War
# Princess Mononoke2019 Re-release
# Princess Mononoke2019 Re-release
# Luka Chuppi
# The Souvenir
# Marianne & Leonard: Words of Love
# Kiki's Delivery Service2019 Re-release
# Kinky Boots the Musical
# Pati Patni Aur Woh
# Howl's Moving Castle2019 Re-release
# Woman at War
# Alien2019 Re-release
# Climax
# Transit
# Student of the Year 2
# I Love Lucy: A Colorized Celebration
# Joni 75: A Birthday Celebration
# More Than Blue
# The Captain
# Non-Fiction
# Spirits in the Forest
# Raise Hell: The Life & Times of Molly Ivins
# Dirty Dancing2019 Re-release
# American Masters: Miles Davis: Birth of the Cool
# The Muppet Movie2019 Re-release
# The White Storm 2: Drug Lords
# The White Storm 2: Drug Lords
# The Chaperone
# To Kill a Mockingbird2019 Re-release
# The Public
# My Fair Lady2019 Re-release
# My Fair Lady2019 Re-release
# Fiddler: A Miracle of Miracles
# Everybody's Everything
# DCI 2019: Big, Loud & Live 16
# A Brother's Love
# A Brother's Love
# Grateful Dead Meet-Up 2019
# Code Geass: Lelouch of the Re;Surrection2019 Re-release
# Long Day's Journey Into Night
# The Spy Behind Home Plate
# Birds of Passage
# Tel Aviv on Fire
# Whisper of the Heart2019 Re-release
# Whisper of the Heart2019 Re-release
# Batla House
# The Russian Five
# 63 Up
# Panipat
# Gorillaz: Reject False Icons
# Teen Spirit
# Killing Sarai
# Ash Is Purest White
# Ben-Hur2019 Re-release
# Fate/stay night [Heaven's Feel] II. lost butterfly
# The Cold Blue
# The Reliant
# The Invisibles
# Meet Me in St. Louis75th Anniversary
# Hello, Dolly!
# Mia and the White Lion
# The Man Who Killed Don Quixote
# The Man Who Killed Don Quixote
# The Secret World of Arrietty2019 Re-release
# The Cure: Anniversary 1978-2018 Live in Hyde Park
# Matthias & Maxime
# The Shawshank Redemption2019 Re-release
# The Tomorrow Man
# Star Trek: The Motion Picture2019 Re-release
# Photograph
# A Silent Voice: The Movie2019 Re-release
# P Storm
# Fleabag
# Sword of Trust
# You Are Here: A Come From Away Story
# Josh Groban Bridges Live from Madison Square Garden
# DanTDM Presents The Contest
# Aquarela
# Aquarela
# K-12
# K-12
# Ask Dr. Ruth
# Line Walker 2: Invisible Spy
# Junglee
# Junglee
# The Giant Spider Invasion
# The Giant Spider Invasion
# Killerman
# The Bravest
# Khalid: Free Spirit
# Mike Wallace Is Here
# The Whistleblower
# The Whistleblower
# I Want to Eat Your Pancreas
# True Grit2019 Re-release
# True Grit2019 Re-release
# The Tale of The Princess Kaguya2019 Re-release
# Shakira in Concert: El Dorado World Tour
# Is It Wrong to Try to Pick Up Girls in a Dungeon - Arrow of the Orion
# Slayer: The Repentless Killogy
# Luzia: Cirque du Soleil in Cinema
# Out of Liberty
# Cunningham
# Mobile Suit Gundam Narrative
# Play the Flute
# Lords of Chaos
# When Harry Met Sally...30th Anniversary
# Canal Street
# Meeting Gorbachev
# The Twilight Zone: A 60th Anniversary Celebration
# The Twilight Zone: A 60th Anniversary Celebration
# Give Me Liberty
# 311 Enlarged to Show Detail 3
# American Woman
# Premier Boxing Champions: PBC on FOX: Spence vs. Porter
# DAZN Boxing: Canelo Alvarez vs. Daniel Jacobs
# DAZN Boxing: Canelo Alvarez vs. Daniel Jacobs
# Mine 9
# Millennium Actress2019 Re-release
# Never Surrender: A Galaxy Quest Documentary
# The Gangster, the Cop, the Devil
# The Karate Kid2019 Re-release
# Hamlet2019 Re-release
# Faith, Hope & Love
# Kathy Griffin: A Hell of a Story
# Synonyms
# Hesburgh
# Forrest Gump2019 Re-release
# Blink of an Eye
# Family
# Mr. KleinRe-release
# The Divine Plan
# To Dust
# The River and the Wall
# Raymonda: Bolshoi Ballet
# Bolshoi Ballet: Raymondadomestic
# Modest Heroes
# India's Most Wanted
# Iyengar: The Man, Yoga, and the Student's Journey
# Marjaavaan
# Marjaavaan
# Bolshoi Ballet: The Golden Age
# Frankie
# The Bad Guys: The Movie
# Bright Ones
# INXS: Baby Live at Wembly Stadium
# Monty Python's Life of Brian2019 Re-release
# Diana Ross: Her Life, Love and Legacy
# Varda by Agnès
# Batman2019 Re-release
# Them That Follow
# Peterloo
# Glory2019 Re-release
# Little Woods
# Little Woods
# Trial by Fire
# War and Peace
# Framing John DeLorean
# Rafiki
# Palau the Movie
# Palau the Movie
# Peppa Celebrates Chinese New Year
# The Zoya Factor
# Paris Is Burning2019 Re-release
# Lost & Found
# Downtown 812019 Re-release
# A Tuba to Cuba
# Citizen K
# Avant qu'on explose
# Ruben Brandt, Collector2018 Re-release
# Be Natural: The Untold Story of Alice Guy-Blaché
# Mob Psycho 100
# The Woman Who Loves Giraffes
# Police Story
# Babylon
# The Audience2019 Re-release
# The Brink
# Belle and Sebastian, Friends for Life2018 Re-release
# Belle and Sebastian, Friends for Life2018 Re-release
# Anthropocene: The Human Epoch
# Miss & Mrs. Cops
# The Divine Fury
# Wonders of the Sea
# Tazza: One-Eyed Jack
# Rojo
# The Image Book
# Margaret Atwood: Live in Cinemas
# Always Miss You
# Mapplethorpe
# Mapplethorpe
# The Crossing
# Loopers: The Caddie's Long Walk
# My Dear Liar
# Sound! Euphonium the Movie - Our Promise: A Brand New Day
# ECCO
# Sonchiriya
# The Chambermaid
# National Theater Live: Cyrano de Bergerac
# Skid Row Marathon
# The Third Wife
# The Third Wife
# High Strung Free Dance2019 Re-release
# Ms. Purple
# Saint Judy
# Ploey
# A Faithful Man
# Fast Color
# Triple Threat
# Savage
# Cliffs of Freedom
# Edie
# Storm Boy
# Free Trip to Egypt2019 Re-release
# The Battle of Jangsari
# Styx
# Batman Returns2019 Re-release
# The Body
# By the Grace of God
# End of the Century
# The Cave
# The Cave
# Sauvage / Wild
# The Mountain
# John Fogerty: 50 Year Trip - Live at Red Rocks
# Mickey and the Bear
# Recorder: The Marion Stokes Project
# Making Waves: The Art of Cinematic Sound
# One Cut of the Dead
# Sympathy for the Devil
# The White Sheik2019 re-release
# Ophelia
# Clinton Road
# The Bounty Killer
# Under the Silver Lake
# The Proposal
# Maze2019 Re-release
# For Sama
# For Sama
# Fagara
# Midnight Family
# Union
# Midnight Traveler
# Charlie Says
# The Raft
# The Raft
# Shed of the Dead
# Batman Forever2019 Re-release
# The Quiet One
# The Death of Dick Long
# The Death of Dick Long
# Britt-Marie Was Here
# The Sower
# Buñuel in the Labyrinth of the Turtles
# Yardie
# Kind Hearts and Coronets2019 Re-release
# Loro
# White Snake
# Ballon
# Love Live! Sunshine!! The School Idol Movie: Over The Rainbow
# Love Live! Sunshine!! The School Idol Movie: Over The Rainbow
# Moonlight Sonata: Deafness in Three Movements
# An Elephant Sitting Still
# An Acceptable Loss
# 10E
# Gift
# Memory: The Origins of Alien
# Pasolini2019 Re-release
# Sorry Angel
# Los Reyes
# The Nun
# Lionel Richie at Glastonbury
# The Ground Beneath My Feet
# Batman & Robin2019 Re-release
# In the Aisles
# Hotel by the River
# The Wind
# The Day Shall Come
# The Day Shall Come
# Donnybrook
# The Disappearance of My Mother
# Hyenas
# Hyenas
# Chasing Einstein
# Little Joe
# Celebration
# Wicked Witches
# Round of Your Life
# The All Americans
# The Gospel of Eureka
# The Sound of Silence
# Prassthanam
# Leo Da Vinci: Mission Mona Lisa
# Armstrong
# Black Mother
# Midnight Diner
# Ode to Joy
# Joseph Pulitzer: Voice of the People
# Starfish
# Trinity Seven The Movie 2: Heavens Library & Crimson Lord
# The Competition2019 Re-release
# Stuffed
# Funan
# Funan
# Wrinkles the Clown
# My Son2019 Re-release
# Combat Obscura
# Screwball
# Touch Me Not
# This One's for the Ladies
# Duet for Cannibals2019 re-release
# Off Season
# Imprisoned
# Quartet
# Quartet
# Cassandro, The Exotico!
# Yomeddine
# 16 Bars
# Vision Portraits
# Olivia
# Streetwise
# When Lambs Become Lions
# The Aspern Papers
# Cracked Up
# The Hottest August
# Frantz Fanon: Black Skin White Mask
# The Meanest Man in Texas
# That Part Feeling - the Universe of Arvo Part
# The Dead Center
# Line of Duty
# Angels Are Made Of Light
# Ghost Fleet
# The Plagiarists
# The Plagiarists
# King of Thieves
# Rosie
# Genesis
# Going Attractions: The Definitive Story of the Movie Palace
# Dying to Survive2019 Re-release
# Spiral Farm
# Spiral Farm
# To Be of Service
# The Miracle of the Little Prince
# Chokehold
# The Gliksmans
# Chulas Fronteras
# The Garden
# The Garden
# Crepitus
# Ballet Blanc
# What You Gonna Do When the World's on Fire?
# Slaughterhouse Rulez
# At War
# I'm Leaving Now
# SGT. Will Gardner
# Tito and the Birds
# The Fate of Lee Khan
# State Like Sleep
# Chinese Portrait
# La Flor
# Mother of a Day
# Rottentail
# Another Day of Life
# Chasing Portraits
# The Kindness of Strangers
# Joan the Maid 1: The Battles
# TINY: The Life of Erin Blackwell
# I Lost Albert2019 Re-release
# In Safe Hands
# Little Q

# %%
so_far = summaries, weeklies, imdb_urls
pickle.dump(so_far, open("in_progress.p", "wb"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-6bd98e5b636c> in <module>
# ----> 1 so_far = summaries, imdbs, imdb_urls
#       2 pickle.dump(so_far, open("in_progress.p", "wb"))
#
# NameError: name 'imdbs' is not defined

# %%
movielibrary = pickle.load(open("in_progress.p", "rb"))

# %%
summaries, weeklies, imdb_urls = movielibrary

# %%
imdbs = scrape_all_imdbs(imdb_urls)

# %%
all_frames = weeklies, summaries, imdbs

pickle.dump(all_frames, open("Scraped_data.p", "wb"))
